# %% [markdown]
# # Clustering for product mix
#
# In this notebook, I build a simple clustering model to cluster product and try to infer a simple insightfull view into clusters of products. Outline of this notebook:
# - A. Load and merge data from data warehouse (dimensional data)
# - B. Perform feauture engineering and build features vector for each product
# - C. Clustering and analyze clusters

# %% [markdown]
# ## A. Load the data from Data Warehouse

# %% [markdown]
# ### Establishing the connection

# %%
from sqlalchemy.schema import CreateSchema
from sqlalchemy import create_engine
import pandas as pd

from dotenv import load_dotenv
import os

os.chdir(os.path.abspath('..'))

load_dotenv()
# Out:
# True

# %%
server_name = os.getenv('POSTGRESQL_SERVER_NAME')
database_name = os.getenv('POSTGRESQL_DATABASE_NAME')
username = os.getenv('POSTGRESQL_USER_NAME')
password = os.getenv('POSTGRESQL_PASSWORD')
driver_name = os.getenv('POSTGRESQL_DRIVER_NAME')

port_number = os.getenv('POSTGRESQL_PORT_NUMBER')

# Modified connection_url with the port:
connection_url = f"postgresql+psycopg2://{username}:{password}@{server_name}:{port_number}/{database_name}"

postgre_engine = create_engine(connection_url)
postgre_engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5432/postgres)

# %% [markdown]
# ### Load Dim dataframe

# %%
dimProductPriceCostHistory_df = pd.read_sql_query('SELECT * FROM dwh."DimPriceCostHistory"', con=postgre_engine)
print("Load Product Price Cost History dimension successfully!")

dimDate_df = pd.read_sql_query('SELECT * FROM dwh."DimDate"', con=postgre_engine)

dimProductPriceCostHistory_df.info()
# Out:
# Load Product Price Cost History dimension successfully!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HistoryKey    395 non-null    int64
#  1   StandardCost  395 non-null    float64
#  2   ListPrice     395 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 9.4 KB

# %% [markdown]
# ### Load the fact dataset

# %%
factProductSales_df = pd.read_sql_query('SELECT * FROM dwh."FactProductSales"', con=postgre_engine)
# factProductSales_df['OrderQty'] = factProductSales_df['OrderQty'].astype('int32')

factProductSales_df.info()

print("-"*40)

print(f"Purchase history recorded from {factProductSales_df['OrderDate'].min()} to {factProductSales_df['OrderDate'].max()}")
print(f"Total number of customers: {factProductSales_df['CustomerID'].nunique()}")

factProductSales_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121246 entries, 0 to 121245
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ProductID     121246 non-null  int64
#  1   OrderQty      121246 non-null  float64
#  2   LineTotal     121246 non-null  float64
#  3   SalesOrderID  121246 non-null  int64
#  4   OrderDate     121246 non-null  datetime64[ns]
#  5   CustomerID    121246 non-null  int64
#  6   HistoryKey    121246 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(4)
# memory usage: 6.5 MB
# ----------------------------------------
# Purchase history recorded from 2011-05-31 00:00:00 to 2014-06-30 00:00:00
# Total number of customers: 19119
#    ProductID  OrderQty  LineTotal  SalesOrderID  OrderDate  CustomerID  \
# 0        707       1.0    20.1865         43665 2011-05-31       29580
# 1        707       2.0    40.3730         43668 2011-05-31       29614
# 2        707       4.0    80.7460         43673 2011-05-31       29844
# 3        707       1.0     0.0000         43677 2011-05-31       29824
# 4        707       1.0   -20.1865         43678 2011-05-31       29889
#
#    HistoryKey
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %% [markdown]
# ### Join together to get final table

# %%
from datetime import datetime

# Get the corresponding Cost in intervals
factProductSales_df = pd.merge(factProductSales_df, dimProductPriceCostHistory_df[['HistoryKey', 'StandardCost']], 
                               on='HistoryKey', how='left')
factProductSales_df.drop(columns=['HistoryKey'], inplace=True)

# Calculate profit
factProductSales_df['profit'] = factProductSales_df['LineTotal'] - factProductSales_df['StandardCost'] * factProductSales_df['OrderQty']
factProductSales_df.to_csv('data/factProductSales_with_profit.csv', index=False)

factProductSales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121246 entries, 0 to 121245
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ProductID     121246 non-null  int64
#  1   OrderQty      121246 non-null  float64
#  2   LineTotal     121246 non-null  float64
#  3   SalesOrderID  121246 non-null  int64
#  4   OrderDate     121246 non-null  datetime64[ns]
#  5   CustomerID    121246 non-null  int64
#  6   StandardCost  121246 non-null  float64
#  7   profit        121246 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(3)
# memory usage: 7.4 MB

# %% [markdown]
# ## B. Feature Engineering
#
# In this stage, we process and group the data to get feature matrix:
# - `profit`: total profit that a single product have returned
# - `profit_margin`: total profit that a single product have returned
# - `average_unit_price`: average price of a product, compute as division of total LineTotal by OrderQty
# - `order_frequency`: number of orders that do have this product
# - `nunique_customer`: number of unique customer purchase at least 1 item of this product
# - `customer_loyalty`: avarage number of orders that each customer make
# - `profit_growth`: growth ratio of profit in last 1 year compared to overall, compute as division of difference between profit and overall_profit
# - `selling_duration`: the duration from the first day of selling

# %% [markdown]
# #### First, define the dataframe of each product and load information into that table

# %%
from datetime import datetime

FINAL_DATE = factProductSales_df['OrderDate'].max() + pd.Timedelta(days=1)      # datetime(2014, 7, 1)
FIRST_DATE = datetime(2011, 7, 1)
QUARTILE_OF_YEAR = 6   # 6 months per interval
ACTIVE_TIME_MOCK = FINAL_DATE - pd.Timedelta(days=365)

print("Get the up-to-date active information from {}...".format(ACTIVE_TIME_MOCK))

filtered_df = factProductSales_df[factProductSales_df['OrderDate'] >= ACTIVE_TIME_MOCK]
print(f"Number of active products: {filtered_df['ProductID'].nunique()}")

product_df = filtered_df.groupby('ProductID').aggregate({
    'OrderQty': 'sum',
    'LineTotal': 'sum',
    'profit': 'sum',
    'CustomerID': 'nunique',
    'SalesOrderID': 'nunique'
}).rename(columns={
    'CustomerID': 'nunique_customer',
    'SalesOrderID': 'order_frequency',
})

product_df['average_unit_price'] = product_df['LineTotal'] / product_df['OrderQty']
product_df['profit_margin'] = product_df['profit'] / product_df['LineTotal']
product_df['customer_loyalty'] = product_df['order_frequency'] / product_df['nunique_customer']
product_df['avg_quantity_sold'] = product_df['OrderQty'] / product_df['order_frequency']

product_df.head()
# Out:
# Get the up-to-date active information from 2013-07-01 00:00:00...
# Number of active products: 179
#            OrderQty      LineTotal        profit  nunique_customer  \
# ProductID
# 707          3698.0  107617.994214  59224.856814              2207
# 708          3750.0  106567.132546  57493.507546              2097
# 711          3754.0  107067.629506  57941.659306              2125
# 712          4296.0   30542.493847    804.293047              2232
# 713           424.0   21195.760000   4875.024800               421
#
#            order_frequency  average_unit_price  profit_margin  \
# ProductID
# 707                   2434           29.101675       0.550325
# 708                   2333           28.417902       0.539505
# 711                   2366           28.520946       0.541169
# 712                   2511            7.109519       0.026334
# 713                    424           49.990000       0.230000
#
#            customer_loyalty  avg_quantity_sold
# ProductID
# 707                1.102855           1.519310
# 708                1.112542           1.607372
# 711                1.113412           1.586644
# 712                1.125000           1.710872
# 713                1.007126           1.000000

# %% [markdown]
# ### Retrievel the performance growth

# %%
# Get the first date a product is sold
first_date = factProductSales_df.groupby('ProductID').aggregate({
    'OrderDate': 'min'
})['OrderDate']

first_date = (FINAL_DATE - first_date).dt.days

product_df['selling_duration'] = product_df.index.map(first_date)
product_df['overall_revenue'] = factProductSales_df.groupby('ProductID').aggregate({
    'LineTotal': 'sum'
})['LineTotal']

product_df['overall_revenue'] = (product_df['overall_revenue'] / product_df['selling_duration'] * 365)
product_df['revenue_growth'] = product_df['LineTotal'] / product_df['overall_revenue']

product_df.head()
# Out:
#            OrderQty      LineTotal        profit  nunique_customer  \
# ProductID
# 707          3698.0  107617.994214  59224.856814              2207
# 708          3750.0  106567.132546  57493.507546              2097
# 711          3754.0  107067.629506  57941.659306              2125
# 712          4296.0   30542.493847    804.293047              2232
# 713           424.0   21195.760000   4875.024800               421
#
#            order_frequency  average_unit_price  profit_margin  \
# ProductID
# 707                   2434           29.101675       0.550325
# 708                   2333           28.417902       0.539505
# 711                   2366           28.520946       0.541169
# 712                   2511            7.109519       0.026334
# 713                    424           49.990000       0.230000
#
#            customer_loyalty  avg_quantity_sold  selling_duration  \
# ProductID
# 707                1.102855           1.519310              1127
# 708                1.112542           1.607372              1127
# 711                1.113412           1.586644              1127
# 712                1.125000           1.710872              1127
# 713                1.007126           1.000000               392
#
#            overall_revenue  revenue_growth
# ProductID
# 707           51045.234581        2.108287
# 708           52009.069206        2.049011
# 711           53511.182405        2.000846
# 712           16564.736905        1.843826
# 713           19968.582015        1.061455

# %% [markdown]
# ### Prepare final dataframe

# %%
FEATURES = ['profit', 'profit_margin', 'average_unit_price', 'order_frequency', 'avg_quantity_sold', 
            'nunique_customer', 'customer_loyalty', 'revenue_growth', 'selling_duration']

feature_matrix = product_df[FEATURES]
feature_matrix.info()

feature_matrix.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 179 entries, 707 to 999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   profit              179 non-null    float64
#  1   profit_margin       179 non-null    float64
#  2   average_unit_price  179 non-null    float64
#  3   order_frequency     179 non-null    int64
#  4   avg_quantity_sold   179 non-null    float64
#  5   nunique_customer    179 non-null    int64
#  6   customer_loyalty    179 non-null    float64
#  7   revenue_growth      179 non-null    float64
#  8   selling_duration    179 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 14.0 KB
#               profit  profit_margin  average_unit_price  order_frequency  \
# count     179.000000     179.000000          179.000000       179.000000
# mean    34808.895395       0.189136          435.025974       437.067039
# std     89918.349152       0.204858          522.892602       641.380031
# min    -22892.137930      -0.216766            2.165137         3.000000
# 25%        55.021450       0.001589           37.180113       125.000000
# 50%      5817.143300       0.155466          201.776466       207.000000
# 75%     31825.228400       0.260000          602.346000       518.000000
# max    516457.725336       0.626001         1839.894465      4486.000000
#
#        avg_quantity_sold  nunique_customer  customer_loyalty  revenue_growth  \
# count         179.000000        179.000000        179.000000      179.000000
# mean            2.152887        350.687151          1.582445        0.917317
# std             0.716029        605.908337          0.470010        0.247979
# min             1.000000          3.000000          1.000000        0.302131
# 25%             1.767054         61.000000          1.222062        0.826646
# 50%             2.090909        116.000000          1.502392        0.902798
# 75%             2.480305        383.000000          1.892916        1.008471
# max             5.750422       4116.000000          2.923077        2.108287
#
#        selling_duration
# count        179.000000
# mean         530.608939
# std          234.921199
# min          392.000000
# 25%          397.000000
# 50%          397.000000
# 75%          762.000000
# max         1127.000000

# %% [markdown]
# ## C. Perform Clustering and Analyzing

# %%
from sklearn.preprocessing import StandardScaler

MATRIX_FEATURES = ['profit', 'profit_margin', 'average_unit_price', 'avg_quantity_sold', 
            'nunique_customer', 'customer_loyalty', 'revenue_growth', 'selling_duration']

data = feature_matrix[MATRIX_FEATURES].to_numpy()
data = StandardScaler().fit_transform(data)

print("Feature matrix shape:", data.shape)

print("First 5 rows of the feature matrix:")
for row in data[:5]:
    print(row)
# Out:
# Feature matrix shape: (179, 8)
# First 5 rows of the feature matrix:
# [ 0.27229648  1.76806626 -0.77848288 -0.88733026  3.07227974 -1.02324549
#   4.81617112  2.54580673]
# [ 0.25298778  1.71510194 -0.77979422 -0.76399768  2.89022488 -1.00257709
#   4.57646366  2.54580673]
# [ 0.25798575  1.7232461  -0.7795966  -0.79302792  2.93656612 -1.00072079
#   4.38169026  2.54580673]
# [-0.3792328  -0.7969409  -0.8206595  -0.61904549  3.11365584 -0.97599632
#   3.74671698  2.54580673]
# [-0.33383438  0.2000334  -0.73842318 -1.61462808  0.11637087 -1.22749064
#   0.58288415 -0.59167817]

# %% [markdown]
# ### Perform clustering

# %%
from sklearn.cluster import KMeans

N_CLUSTERS = 4 
SAVED_PATH = 'data/product_clusters.csv'

labels = KMeans(n_clusters=N_CLUSTERS, random_state=42).fit_predict(data)

for cluster_id in range(N_CLUSTERS):
    cluster_size = (labels == cluster_id).sum()
    print(f"Cluster {cluster_id}: {cluster_size} products")

feature_matrix['cluster_id'] = labels

feature_matrix.reset_index().to_csv(SAVED_PATH, index=False)
print(f"Saved clustering results to '{SAVED_PATH}'...")

feature_matrix.head()
# Out:
# Cluster 0: 98 products
# Cluster 1: 29 products
# Cluster 2: 28 products
# Cluster 3: 24 products
# Saved clustering results to 'data/product_clusters.csv'...
# /var/folders/gp/jhdxg4dj4cvg1nrkhvs6lh040000gn/T/ipykernel_18402/772695530.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_matrix['cluster_id'] = labels
#                  profit  profit_margin  average_unit_price  order_frequency  \
# ProductID
# 707        59224.856814       0.550325           29.101675             2434
# 708        57493.507546       0.539505           28.417902             2333
# 711        57941.659306       0.541169           28.520946             2366
# 712          804.293047       0.026334            7.109519             2511
# 713         4875.024800       0.230000           49.990000              424
#
#            avg_quantity_sold  nunique_customer  customer_loyalty  \
# ProductID
# 707                 1.519310              2207          1.102855
# 708                 1.607372              2097          1.112542
# 711                 1.586644              2125          1.113412
# 712                 1.710872              2232          1.125000
# 713                 1.000000               421          1.007126
#
#            revenue_growth  selling_duration  cluster_id
# ProductID
# 707              2.108287              1127           1
# 708              2.049011              1127           1
# 711              2.000846              1127           1
# 712              1.843826              1127           1
# 713              1.061455               392           1

# %%
from matplotlib import pyplot as plt
import numpy as np

n_cols = 3                          # number of columns you want
n = len(FEATURES)                   # number of boxplots
n_rows = int(np.ceil(n / n_cols))   # compute required rows

fig, axes = plt.subplots(n_rows, n_cols, figsize=(6*n_cols, 5*n_rows))
axes = np.ravel(axes)               # flatten to 1D list

for i, col in enumerate(FEATURES):
    ax = axes[i]
    feature_matrix.boxplot(column=col, by='cluster_id', ax=ax)
    ax.set_title(col)
    ax.set_xlabel("cluster_id")
    ax.set_ylabel("Value")

# Hide unused subplots
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.suptitle("")        # global title
plt.tight_layout()
plt.subplots_adjust(top=0.95)
plt.savefig("fig/all_boxplots.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

profit_percent = feature_matrix.groupby('cluster_id').sum()['profit'].values
profit_percent = profit_percent / profit_percent.sum() * 100

colors_mapping = ["#ee1e1e","#2c8ae8","#26eb26","#cb9f73"]

plt.figure(figsize=(10, 6))

plt.subplot(1, 2, 1)
plt.pie(profit_percent,
    labels=[f'Cluster {i}' for i in range(len(profit_percent))],
    autopct='%1.1f%%',
    startangle=90,
    colors=colors_mapping)
plt.title('Profit Percentage by Cluster')

plt.subplot(1, 2, 2)
plt.pie(feature_matrix['cluster_id'].value_counts().sort_index(),
    labels=[f'Cluster {i}' for i in range(len(profit_percent))],
    autopct='%1.1f%%',
    startangle=90,
    colors=colors_mapping)
plt.title('Product Count Percentage by Cluster')

plt.show()

# %%
filtered_df.loc[:, 'cluster_id'] = filtered_df['ProductID'].map(feature_matrix['cluster_id'])

# Get number of unique customers per cluster
customer_per_cluster = filtered_df.groupby('cluster_id')['CustomerID'].nunique() / filtered_df['CustomerID'].nunique() * 100

# Draw bar chart
plt.figure(figsize=(8, 5))
bars = plt.bar(customer_per_cluster.index, customer_per_cluster.values, color=colors_mapping)
plt.title('Percentage of Customers by Cluster')
plt.xlabel('Cluster ID')
plt.ylabel('Percentage of Unique Customers (%)')
plt.xticks(customer_per_cluster.index)
plt.grid()
plt.legend(bars, [f'Cluster {i}' for i in customer_per_cluster.index])
# plt.savefig("fig/customer_percentage_by_cluster.png", dpi=300)
plt.show()

# %% [markdown]
# ### Count number of clusters for each subcategories

# %%
dfDimProduct = pd.read_sql_query('SELECT * FROM dwh."DimProduct"', con=postgre_engine)
dfDimSubcategory = pd.read_sql_query('SELECT * FROM dwh."DimProductSubcategory"', con=postgre_engine)
dfDimCategory = pd.read_sql_query('SELECT * FROM dwh."DimProductCategory"', con=postgre_engine)

dfDimProduct.set_index('ProductID', inplace=True)
dfDimSubcategory.set_index('ProductSubcategoryID', inplace=True)
dfDimCategory.set_index('ProductCategoryID', inplace=True)

feature_matrix['ProductSubcategoryID'] = dfDimProduct.loc[feature_matrix.index, 'ProductSubcategoryID']
feature_matrix['CategoryID'] = dfDimSubcategory.loc[feature_matrix['ProductSubcategoryID'], 'ProductCategoryID'].values
feature_matrix['CategoryName'] = dfDimCategory.loc[feature_matrix['CategoryID'], 'Name'].values
feature_matrix['SubCategoryName'] = dfDimSubcategory.loc[feature_matrix['ProductSubcategoryID'], 'Name'].values

# Group and count number of clusters for each products subcategory
subcategory_cluster_counts = feature_matrix.groupby(['CategoryName', 'ProductSubcategoryID', 'cluster_id']).size().unstack(fill_value=0)
category_cluster_counts = feature_matrix.groupby(['CategoryName', 'cluster_id']).size().unstack(fill_value=0)

feature_matrix.to_sql(schema='dwh', name='ProductClusterAssignments', con=postgre_engine, if_exists='replace')

print("Width dimension analysis:")
display(category_cluster_counts)
# Out:
# Width dimension analysis:
# /var/folders/gp/jhdxg4dj4cvg1nrkhvs6lh040000gn/T/ipykernel_18402/4147445836.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_matrix['ProductSubcategoryID'] = dfDimProduct.loc[feature_matrix.index, 'ProductSubcategoryID']
# cluster_id     0   1   2   3
# CategoryName
# Accessories    1  21   0   0
# Bikes         33   0   3  24
# Clothing       9   8   3   0
# Components    55   0  22   0

# %%
# Plot pie chart for each category
# Draw as 4 subfigures with ncols = 2

fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.ravel()

colors_mapping = ["#ee1e1e","#2c8ae8","#26eb26","#cb9f73"]

for i, (category_id, row) in enumerate(category_cluster_counts.iterrows()):
    ax = axes[i]

    # Filter out zero values
    idx = row > 0
    counts = row[idx].values
    total = counts.sum()
    ax.pie(counts,
           labels=[f'Cluster {j}' for j in range(len(row)) if idx[j]],
           autopct=lambda pct: f'{int(round(pct * total / 100.0))}',
           startangle=90,
           colors=[colors_mapping[j] for j in range(len(row)) if idx[j]])
    ax.set_title(f'Category: {category_id}')

plt.savefig('fig/CategoryDistribution.png', dpi=300)

# %%
# Plot pie chart for each category
# Draw as 4 subfigures with ncols = 2

fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.ravel()

subcategory_cluster_counts = feature_matrix[feature_matrix['CategoryName'] == 'Bikes'].groupby(['SubCategoryName', 'cluster_id']).size().unstack(fill_value=0)

display(subcategory_cluster_counts)

for i, (subcategory_id, row) in enumerate(subcategory_cluster_counts.iterrows()):
    ax = axes[i]

display(subcategory_cluster_counts)
display(category_cluster_counts)
# Out:
# cluster_id        0  2   3
# SubCategoryName
# Mountain Bikes   14  0   6
# Road Bikes        5  3  10
# Touring Bikes    14  0   8
# cluster_id        0  2   3
# SubCategoryName
# Mountain Bikes   14  0   6
# Road Bikes        5  3  10
# Touring Bikes    14  0   8
# cluster_id     0   1   2   3
# CategoryName
# Accessories    1  21   0   0
# Bikes         33   0   3  24
# Clothing       9   8   3   0
# Components    55   0  22   0
